# %% [markdown]
# 🧩 Exercício 11: Sistema de pedidos (desafio estilo entrevista)
#
# Crie:
#
# - Produto (nome, preço)
# - Pedido (lista de produtos)
#
# Pedido deve:
#
# 1 - adicionar produto
#
# 2 - calcular total
#
# 3 - aplicar desconto se total > 100
