# %% [markdown]
# 🧩 Exercício 10: Sistema de veículos
#
# Crie:
#
# Classe base:
#
#  - Veiculo (marca, modelo)
#
# Classes filhas:
#
#  - Carro
#  - Moto
#
# Cada uma deve ter:
#
# 1 - método tipo() retornando o tipo
