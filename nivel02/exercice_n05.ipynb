# %% [markdown]
# 🧩 Exercício 5: Aluno
#
# Crie uma classe Aluno com:
#
# * nome
# * lista de notas
#
# Métodos:
#
# 1 - adicionar nota
#
# 2 - calcular média
#
# 3 - verificar se foi aprovado (média >= 7)
