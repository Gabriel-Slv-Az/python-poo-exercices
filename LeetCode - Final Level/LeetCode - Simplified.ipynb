# %% [markdown]
# 🧠 Desafio final (nível LeetCode simplificado)
#
# 🧩 Exercício 12: Sistema de biblioteca
#
# Crie classes:
#
# 📚 Livro
#
#  - nome
#  - autor
#  - disponível (True/False)
#
# 👤 Usuario
#
#  - nome
#  - livros emprestados
#
# 📦 Biblioteca
#
#  - lista de livros
#
# Funcionalidades:
#
# 1 - emprestar livro (se disponível)
#
# 2 - devolver livro
#
# 3 - listar livros disponíveis
